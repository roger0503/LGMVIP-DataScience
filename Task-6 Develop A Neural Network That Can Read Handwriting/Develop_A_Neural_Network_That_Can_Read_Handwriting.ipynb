# %% [markdown]
# # LGMVIP Data Science Internship

# %% [markdown]
# ## Task6 - Develop A Neural Network That Can Read Handwriting

# %% [markdown]
# ## Author : Taabish Farid Khan

# %% [markdown]
# ### Importing the libraries

# %%
import numpy as np
from tensorflow.keras.datasets.mnist import load_data
from tensorflow.keras import Sequential
from tensorflow.keras.layers  import  Conv2D,MaxPool2D,Dense,Flatten,Dropout
from tensorflow.keras.utils import plot_model
import matplotlib.pyplot as plt

# %% [markdown]
# ### Loading data using Keras Dataset library

# %%
(x_train,y_train),(x_test,y_test)=load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# ### Changing data into Gray Scale

# %%
x_train=x_train.reshape(-1,28,28,1)
x_test=x_test.reshape(-1,28,28,1)

# %%
print(x_test.shape)
print(x_train.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (10000, 28, 28, 1)
# (60000, 28, 28, 1)
# (60000,)
# (10000,)

# %%
x_trains=x_train.astype('float32')/255.0
x_tests=x_test.astype('float32')/255.0
print(x_trains.shape)
print(x_tests.shape)
# Out:
# (60000, 28, 28, 1)
# (10000, 28, 28, 1)

# %%
fig=plt.figure(figsize=(15,3))
for i in range(20):
  ax=fig.add_subplot(2,10,i+1,xticks=[],yticks=[])
  ax.imshow(np.squeeze(x_train[i]),cmap='gray')
  ax.set_title(y_train[i])

# %%
x=x_trains.shape[1:]

# %% [markdown]
# ### Creating Model

# %%
model=Sequential()
model.add(Conv2D(32,(3,3),activation="relu",input_shape=(28,28,1)))
model.add(MaxPool2D((2,2)))
model.add(Conv2D(64,(3,3),activation='relu'))
model.add(MaxPool2D((2,2)))
model.add(Conv2D(128,(3,3),activation='relu'))
model.add(MaxPool2D((2,2)))
model.add(Dropout(0.5))
model.add(Flatten())
model.add(Dense(500,activation="relu"))
model.add(Dense(10,activation="Softmax"))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 3, 3, 128)         73856
#
#  max_pooling2d_2 (MaxPooling  (None, 1, 1, 128)        0
#  2D)
#
#  dropout (Dropout)           (None, 1, 1, 128)         0
#
#  flatten (Flatten)           (None, 128)               0
#
#  dense (Dense)               (None, 500)               64500
#
#  dense_1 (Dense)             (None, 10)                5010
#
# =================================================================
# Total params: 162,182
# Trainable params: 162,182
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer="adam",loss='sparse_categorical_crossentropy',metrics=['accuracy'])
history=model.fit(x_trains,y_train,epochs=10,batch_size=32,validation_split=0.1)
# Out:
# Epoch 1/10
# 1688/1688 [==============================] - 54s 32ms/step - loss: 0.3329 - accuracy: 0.8953 - val_loss: 0.0803 - val_accuracy: 0.9773
# Epoch 2/10
# 1688/1688 [==============================] - 53s 32ms/step - loss: 0.1241 - accuracy: 0.9632 - val_loss: 0.0544 - val_accuracy: 0.9847
# Epoch 3/10
# 1688/1688 [==============================] - 53s 32ms/step - loss: 0.0958 - accuracy: 0.9721 - val_loss: 0.0516 - val_accuracy: 0.9855
# Epoch 4/10
# 1688/1688 [==============================] - 53s 31ms/step - loss: 0.0796 - accuracy: 0.9761 - val_loss: 0.0471 - val_accuracy: 0.9862
# Epoch 5/10
# 1688/1688 [==============================] - 53s 31ms/step - loss: 0.0711 - accuracy: 0.9789 - val_loss: 0.0503 - val_accuracy: 0.9858
# Epoch 6/10
# 1688/1688 [==============================] - 52s 31ms/step - loss: 0.0611 - accuracy: 0.9819 - val_loss: 0.0406 - val_accuracy: 0.9888
# Epoch 7/10
# 1688/1688 [==============================] - 53s 31ms/step - loss: 0.0538 - accuracy: 0.9838 - val_loss: 0.0415 - val_accuracy: 0.9870
# Epoch 8/10
# 1688/1688 [==============================] - 53s 31ms/step - loss: 0.0499 - accuracy: 0.9844 - val_loss: 0.0446 - val_accuracy: 0.9895
# Epoch 9/10
# 1688/1688 [==============================] - 53s 31ms/step - loss: 0.0455 - accuracy: 0.9864 - val_loss: 0.0380 - val_accuracy: 0.9893
# Epoch 10/10
# 1688/1688 [==============================] - 53s 31ms/step - loss: 0.0428 - accuracy: 0.9868 - val_loss: 0.0371 - val_accuracy: 0.9897

# %% [markdown]
# ### Plotting Accuracy of Model

# %%
plt.title("Accuracy and Loss")
plt.xlabel("Epoch")
plt.ylabel("acc/Loss")
plt.plot(history.history['accuracy'],label='acc')
plt.plot(history.history["val_accuracy"],label='val')
plt.show()

# %%
plt.title("Accuracy and Loss")
plt.xlabel("Epoch")
plt.ylabel("acc/Loss")
plt.plot(history.history['loss'],label='acc')
plt.plot(history.history["val_loss"],label='val')
plt.show()

# %% [markdown]
# ### Testing Our Model

# %%
image=x_trains[5]
plt.imshow(np.squeeze(image),cmap="gray")

# %%
image=image.reshape(-1,28,28,1)
pred=model.predict([image])
np.argmax(pred)
# Out:
# 2

# %% [markdown]
# ## Thank You
